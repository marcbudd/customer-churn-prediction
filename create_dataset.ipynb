# %%
import pandas as pd

# %% [markdown]
# ## Look at files

# %%
df_churn = pd.read_excel('data/CustomerChurn.xlsx')
df_churn.tail()
# Out:
#       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 7038     810338  6840-RESVB             No     Yes        Yes      24
# 7039     230811  2234-XADUH             No     Yes        Yes      72
# 7040     155157  4801-JZAZL             No     Yes        Yes      11
# 7041     731782  8361-LTMKD            Yes     Yes         No       4
# 7042     353947  3186-AJIEK             No      No         No      66
#
#      Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 7038           Yes               Yes              DSL             Yes  ...
# 7039           Yes               Yes      Fiber optic              No  ...
# 7040            No  No phone service              DSL             Yes  ...
# 7041           Yes               Yes      Fiber optic              No  ...
# 7042           Yes                No      Fiber optic             Yes  ...
#
#      Device Protection Tech Support Streaming TV Streaming Movies  \
# ...

# %%
df_demographics = pd.read_excel('data/Telco_customer_churn_demographics.xlsx')
df_demographics.tail()
# Out:
#      Customer ID  Count  Gender  Age Under 30 Senior Citizen Married  \
# 7038  2569-WGERO      1  Female   30       No             No      No
# 7039  6840-RESVB      1    Male   38       No             No     Yes
# 7040  2234-XADUH      1  Female   30       No             No     Yes
# 7041  4801-JZAZL      1  Female   32       No             No     Yes
# 7042  3186-AJIEK      1    Male   44       No             No      No
#
#      Dependents  Number of Dependents
# 7038         No                     0
# 7039        Yes                     2
# 7040        Yes                     2
# 7041        Yes                     2
# 7042         No                     0

# %%
df_location = pd.read_excel('data/Telco_customer_churn_location.xlsx')
df_location.tail()
# Out:
#      Location ID Customer ID  Count        Country       State          City  \
# 7038  XVCVGG7664  2569-WGERO      1  United States  California       Landers
# 7039  NOTKAT3139  6840-RESVB      1  United States  California      Adelanto
# 7040  IIQJBU2929  2234-XADUH      1  United States  California         Amboy
# 7041  PBNAHR7564  4801-JZAZL      1  United States  California  Angelus Oaks
# 7042  TJZLUX4957  3186-AJIEK      1  United States  California  Apple Valley
#
#       Zip Code                Lat Long   Latitude   Longitude
# 7038     92285  34.341737, -116.539416  34.341737 -116.539416
# 7039     92301  34.667815, -117.536183  34.667815 -117.536183
# 7040     92304  34.559882, -115.637164  34.559882 -115.637164
# 7041     92305     34.1678, -116.86433  34.167800 -116.864330
# 7042     92308  34.424926, -117.184503  34.424926 -117.184503

# %%
df_population = pd.read_excel('data/Telco_customer_churn_population.xlsx')
df_population.tail()
# Out:
#         ID  Zip Code  Population
# 1666  1667     96145        4002
# 1667  1668     96146         942
# 1668  1669     96148         678
# 1669  1670     96150       33038
# 1670  1671     96161       15783

# %%
df_services = pd.read_excel('data/Telco_customer_churn_services.xlsx')
df_services.tail()
# Out:
#          Service ID Customer ID  Count Quarter Referred a Friend  \
# 7038  JIVEOZUQQ2296  2569-WGERO      1      Q3                No
# 7039  OIQWIUTDY3518  6840-RESVB      1      Q3               Yes
# 7040  QSHQPZAYF6519  2234-XADUH      1      Q3               Yes
# 7041  PMJLYZGVQ7211  4801-JZAZL      1      Q3               Yes
# 7042  BILLTTPVG8428  3186-AJIEK      1      Q3                No
#
#       Number of Referrals  Tenure in Months    Offer Phone Service  \
# 7038                    0                72      NaN           Yes
# 7039                    1                24  Offer C           Yes
# 7040                    4                72      NaN           Yes
# 7041                    1                11      NaN            No
# 7042                    0                66      NaN           Yes
#
#       Avg Monthly Long Distance Charges  ... Unlimited Data        Contract  \
# 7038                              22.77  ...             No        Two Year
# ...

# %%
df_status = pd.read_excel('data/Telco_customer_churn_status.xlsx')
df_status.tail()
# Out:
#        Status ID Customer ID  Count Quarter  Satisfaction Score  \
# 7038  HNJTLH8249  2569-WGERO      1      Q3                   5
# 7039  SJJDWW6147  6840-RESVB      1      Q3                   3
# 7040  AODCBE7865  2234-XADUH      1      Q3                   4
# 7041  GLQPEW3973  4801-JZAZL      1      Q3                   4
# 7042  KCNRPQ8327  3186-AJIEK      1      Q3                   4
#
#      Customer Status Churn Label  Churn Value  Churn Score  CLTV  \
# 7038          Stayed          No            0           45  5306
# 7039          Stayed          No            0           59  2140
# 7040          Stayed          No            0           71  5560
# 7041          Stayed          No            0           59  2793
# 7042          Stayed          No            0           38  5097
#
#      Churn Category Churn Reason
# 7038            NaN          NaN
# 7039            NaN          NaN
# 7040            NaN          NaN
# 7041            NaN          NaN
# ...

# %%
df_churn2 = pd.read_excel('data/Telco_customer_churn.xlsx')
df_churn2.tail()
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# 7038  34.341737, -116.539416  34.341737 -116.539416  Female  ...
# 7039  34.667815, -117.536183  34.667815 -117.536183    Male  ...
# 7040  34.559882, -115.637164  34.559882 -115.637164  Female  ...
# 7041     34.1678, -116.86433  34.167800 -116.864330  Female  ...
# 7042  34.424926, -117.184503  34.424926 -117.184503    Male  ...
#
#             Contract Paperless Billing             Payment Method  \
# ...

# %%
df_churn.columns
# Out:
# Index(['LoyaltyID', 'Customer ID', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn'],
#       dtype='object')

# %% [markdown]
# # Merge dataframes

# %%
df = df_churn[['Customer ID', 'Churn']]
df = df.rename(columns={'CustomerID': 'Customer ID'})

# Merge the dataframes

# Demographics
doubled_columns = ['Count']
temp = df_demographics.drop(columns=doubled_columns)
df = df.merge(temp, on='Customer ID', how='inner')

# Location
doubled_columns = ['Count']
temp = df_location.drop(columns=doubled_columns)
df = df.merge(temp, on='Customer ID', how='inner')

# Population
temp = df_population.drop(columns=['ID'])
temp = temp.rename(columns={'Population': 'Zip Code Population'})
df = df.merge(temp, on='Zip Code', how='inner')

# Services
temp = df_services.drop(columns=['Service ID'])
df = df.merge(temp, on='Customer ID', how='inner')

# Status
needed_columns = ['Customer ID', 'Satisfaction Score']
temp = df_status[needed_columns]
df = df.merge(temp, on='Customer ID', how='inner')

df.columns
# Out:
# Index(['Customer ID', 'Churn', 'Gender', 'Age', 'Under 30', 'Senior Citizen',
#        'Married', 'Dependents', 'Number of Dependents', 'Location ID',
#        'Country', 'State', 'City', 'Zip Code', 'Lat Long', 'Latitude',
#        'Longitude', 'Zip Code Population', 'Count', 'Quarter',
#        'Referred a Friend', 'Number of Referrals', 'Tenure in Months', 'Offer',
#        'Phone Service', 'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Satisfaction Score'],
#       dtype='object')

# %%
df.to_csv('data/churn_data.csv', index=False)
